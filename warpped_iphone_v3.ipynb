# %%
import sys
sys.path.append('/data/yyang/workspace/Iphone-Warp')
from dycheck.dataset.iphonev3 import iPhoneDataset


dataset = iPhoneDataset(
    data_root='data/iphone_sm',
    scene='apple',
    use_undistort=False
)
# Out:
# Warning: image_path not found for reconstruction
# Loading camera parmeters from colmap: 100%|██████████| 1007/1007 [00:00<00:00, 67582.95it/s]

# %%
pixel_a, pixel_b, warpped_pixel_b, valid_mask = dataset.warp_a2b(25,0,25,1)

# %%
import cv2
import matplotlib.pyplot as plt
plt.imshow(pixel_a)

# %%
plt.imshow(pixel_b)

# %%
plt.imshow(warpped_pixel_b)

# %%
plt.imshow(valid_mask)
